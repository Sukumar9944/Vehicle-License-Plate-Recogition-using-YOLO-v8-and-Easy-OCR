# %%
# %cd /content/drive/MyDrive/License_Plate_Recognition
# Out:
# /content/drive/MyDrive/License_Plate_Recognition

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# %%
# Train the model
results = model.train(data="data.yaml", epochs=30, imgsz=640, patience = 0)
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
